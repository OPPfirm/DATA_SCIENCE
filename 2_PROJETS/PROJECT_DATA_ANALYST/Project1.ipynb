# %% [markdown]
# # PROJECT 1

# %% [markdown]
# ### Title: Track and Visualize Sales Performance with a Dashboard (Excel)
# Business Problem
# A company wants to track sales performance by region and category to identify areas for improvement.
# Objective
# Create an interactive dashboard to analyze key KPIs such as sales, margins, and regional performance.
# Database
# Superstore Dataset
# Data cleaning and organization. Essential Excel formulas: SUM, SUMIF, AVERAGE, VLOOKUP, INDEX, MATCH. Creation of pivot tables with slicers for easy navigation. Creation of dynamic charts and interactive dashboards.
# Skills to acquire

# %%
import pandas as pd

# %%
# Load the data
df= pd.read_excel("Sample - SuperstoreP1_new.xlsx")

# Read the Excel file back into a DataFrame
df.head()
# Out:
#    Row ID   Order ID         Order Date   Ship Date    Ship Mode        \
# 0        1  CA-2016-152156   11/8/2016    11/11/2016   Second Class
# 1        2  CA-2016-152156   11/8/2016    11/11/2016   Second Class
# 2        3  CA-2016-138688   6/12/2016    6/16/2016    Second Class
# 3        4  US-2015-108966   10/11/2015   10/18/2015   Standard Class
# 4        5  US-2015-108966   10/11/2015   10/18/2015   Standard Class
#
#    Customer ID   Customer Name            Segment       Country         \
# 0  CG-12520      Claire Gute              Consumer      United States
# 1  CG-12520      Claire Gute              Consumer      United States
# 2  DV-13045      Darrin Van Huff          Corporate     United States
# 3  SO-20335      Sean O'Donnell           Consumer      United States
# 4  SO-20335      Sean O'Donnell           Consumer      United States
#
#    City                ... Postal Code   Region    Product ID        \
# ...
