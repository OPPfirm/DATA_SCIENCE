# %% [markdown]
# ## **LIBRAIRIES ET FONCTIONS**

# %%
#Librairies
import numpy as np 
import pandas as pd
import seaborn as sns


#Mes fonctions
path_perso=r"C:\Users\franc\Desktop\FORMATION\DATA_SCIENCE\ML_PRO\DOC"
import sys 
sys.path.append(path_perso)
from perso import  *

# %%
path=r"test_set_perso.csv"
df= pd.read_csv(path)

# %% [markdown]
# ## **LOAD DATASET**

# %% [markdown]
# •   Customer ID : Un identifiant unique pour chaque client
# •   Surname : Le nom de famille du client
# •   Credit Score : Une valeur numérique représentant le score de crédit du client
# •   Geography : Le pays où réside le client (France, Spain ou Germany)
# •   Gender : Le genre du client (Male or Female)
# •   Age : L’âge du client
# •   Tenure : Le nombre d’années pendant lesquelles le client est avec la banque
# •   Balance : Le solde du compte du client
# •   NumOfProducts : Le nombre de produits bancaires utilisés par le client (par exemple, compte d’épargne, carte de crédit)
# •   HasCrCard : Si le client possède une carte de crédit (1 = oui, 0 = non)
# •   IsActiveMember : Si le client est un membre actif (1 = oui, 0 = non)
# •   EstimatedSalary : Le salaire estimé du client
# •   Exited : Si le client a résilié (1 = oui, 0 = non)

# %%
df.head()
# Out:
#        ID  CustomerId     Surname  CreditScore Geography  Gender   Age  \
# 0   24780    15587824        Tuan          729    France  Female  39.0
# 1    3404    15691624  Chidiebere          769    France  Female  33.0
# 2    7416    15778861   Robertson          579     Spain    Male  33.0
# 3   43781    15581626        Long          556    France    Male  36.0
# 4  128000    15585961     Maclean          616    France    Male  40.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       9  149334.84              1        1.0             1.0
# 1       8       0.00              2        0.0             1.0
# 2       3       0.00              2        1.0             0.0
# 3       7       0.00              2        1.0             1.0
# 4       5  134498.95              1        1.0             1.0
#
#    EstimatedSalary  Exited
# 0        170965.53       1
# 1         23067.97       0
# 2        136259.65       0
# 3         37731.95       0
# ...

# %%
df.isna().sum()
## il n'y a pas de nanan dans mon dataset
# Out:
# ID                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28716 entries, 0 to 28715
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               28716 non-null  int64
#  1   CustomerId       28716 non-null  int64
#  2   Surname          28716 non-null  object
#  3   CreditScore      28716 non-null  int64
#  4   Geography        28716 non-null  object
#  5   Gender           28716 non-null  object
#  6   Age              28716 non-null  float64
#  7   Tenure           28716 non-null  int64
#  8   Balance          28716 non-null  float64
#  9   NumOfProducts    28716 non-null  int64
#  10  HasCrCard        28716 non-null  float64
#  11  IsActiveMember   28716 non-null  float64
#  12  EstimatedSalary  28716 non-null  float64
#  13  Exited           28716 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 3.1+ MB

# %%
#df a utiliser 
notuse_col = ["Surname","CustomerId",] #je laisse ID car il est utilise

df=df.drop(columns=notuse_col)

df.head()
# Out:
#        ID  CreditScore Geography  Gender   Age  Tenure    Balance  \
# 0   24780          729    France  Female  39.0       9  149334.84
# 1    3404          769    France  Female  33.0       8       0.00
# 2    7416          579     Spain    Male  33.0       3       0.00
# 3   43781          556    France    Male  36.0       7       0.00
# 4  128000          616    France    Male  40.0       5  134498.95
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1        1.0             1.0        170965.53       1
# 1              2        0.0             1.0         23067.97       0
# 2              2        1.0             0.0        136259.65       0
# 3              2        1.0             1.0         37731.95       0
# 4              1        1.0             1.0         93866.46       0

# %%
df.columns
# Out:
# Index(['ID', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# ## **ANALYSES UNIVARIEES**

# %% [markdown]
# ## **DISCRETE**

# %%
# Générer le graphe
geo_count= df['Geography'].value_counts( sort=True,)

ax = geo_count.plot(kind="bar", edgecolor='black')
plt.xticks(rotation=0)

# Annoter chaque barre avec la valeur
for p in ax.patches:
    ax.annotate(f"{p.get_height():.2f}",             # valeur formatée à 2 décimales
                (p.get_x() + p.get_width() / 2, p.get_height()),  # coordonnées (x,y)
                ha='center', va='bottom')            # alignement

plt.show()

# %%
plot_bar_with_values(series=df["Gender"],normalize=True)
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ## **CONTINUE**

# %%
['CreditScore', 'Age', 'Tenure', 'Balance','NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
print()

# %%
df['CreditScore'].describe().round(2)
# Out:
# count    28716.00
# mean       656.32
# std         80.25
# min        350.00
# 25%        597.00
# 50%        660.00
# 75%        710.00
# max        850.00
# Name: CreditScore, dtype: float64

# %%
#creditScore : score de credit
affichage_hb(data=df,col='CreditScore')

# %%
affichage_hb(data=df,col="Age")
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<Axes: xlabel='Age', ylabel='Count'>, <Axes: xlabel='Age'>],
#        dtype=object))

# %%
df['Tenure'].plot
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<Axes: xlabel='Tenure', ylabel='Count'>, <Axes: xlabel='Tenure'>],
#        dtype=object))

# %%
# Calcul de la matrice de corrélation sur les colonnes numériques
corr_matrix = df.select_dtypes(include=[np.number]).corr()

# Création de la heatmap avec seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Heatmap des corrélations")
plt.show()
