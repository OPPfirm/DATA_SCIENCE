# %% [markdown]
# ## Librairies

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler ,StandardScaler

from sklearn import set_config
set_config(transform_output="pandas")

# %% [markdown]
# ### **Function**

# %%
# fonction
import sys
sys.path.append(r"C:\Users\franc\Desktop\DATA_SCIENCE\ML_PRO\DOC")
from perso import *

# %% [markdown]
# ## **Load Diamonds**

# %%
df= sns.load_dataset("diamonds")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#garder df avec les variables numeriques

df_numeric= df.select_dtypes(exclude="category")
df_numeric.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# #### **NB: verifier toujours les conditions avants d'utiliser un element**
# <style>
#   img {
#     max-width: 20%;
#     height: auto;
#   }
# </style>
# ![image.png](attachment:image.png)

# %%
affichage_hb(data=df_numeric,col="table")

# %%
affichage_hb(data=df_numeric,col='price')

# %%
affichage_hb(data=df_numeric,col='x')

# %%
affichage_hb(data=df_numeric,col='y')

# %%
affichage_hb(data=df_numeric,col='z')

# %%
scaler=MinMaxScaler()
df_minmax = scaler.fit_transform(df_numeric)

df_minmax .describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.124312      0.520817      0.278023      0.194994      0.533627
# std        0.098547      0.039795      0.042971      0.215680      0.104447
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.041580      0.500000      0.250000      0.033735      0.438547
# 50%        0.103950      0.522222      0.269231      0.112180      0.530726
# 75%        0.174636      0.541667      0.307692      0.270219      0.608939
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       0.097360      0.111281
# std        0.019391      0.022192
# min        0.000000      0.000000
# 25%        0.080136      0.091509
# 50%        0.096944      0.111006
# 75%        0.111036      0.127044
# ...

# %%
scaler= StandardScaler()
df_std=scaler.fit_transform(df_numeric)
df_std.describe()
# Out:
#               carat         depth         table         price             x  \
# count  5.394000e+04  5.394000e+04  5.394000e+04  5.394000e+04  5.394000e+04
# mean   2.444878e-16 -3.996902e-15  9.695207e-17 -9.273676e-17  2.782103e-16
# std    1.000009e+00  1.000009e+00  1.000009e+00  1.000009e+00  1.000009e+00
# min   -1.261458e+00 -1.308760e+01 -6.470073e+00 -9.040952e-01 -5.109120e+00
# 25%   -8.395232e-01 -5.231053e-01 -6.521385e-01 -7.476808e-01 -9.103248e-01
# 50%   -2.066210e-01  3.531678e-02 -2.046051e-01 -3.839672e-01 -2.777553e-02
# 75%    5.106683e-01  5.239361e-01  6.904618e-01  3.487866e-01  7.210542e-01
# max    8.886075e+00  1.204139e+01  1.680167e+01  3.732438e+00  4.465203e+00
#
#                   y             z
# count  5.394000e+04  5.394000e+04
# mean  -8.430615e-17 -2.002271e-16
# std    1.000009e+00  1.000009e+00
# min   -5.020931e+00 -5.014556e+00
# 25%   -8.882800e-01 -8.909461e-01
# 50%   -2.147398e-02 -1.237618e-02
# 75%    7.052421e-01  7.103184e-01
# ...

# %%
  
col='carat' 
plt.figure(figsize=(15,5))
sns.histplot(data=df_numeric,x=col ,alpha=0.5,color="tab:blue")
sns.histplot(data=df_minmax ,x=col,alpha=0.5,color="tab:orange")
sns.histplot(data=df_std,x=col,alpha=0.5,color="tab:green")
plt.suptitle("visualisation de la variable {}".format(col))
plt.show()
